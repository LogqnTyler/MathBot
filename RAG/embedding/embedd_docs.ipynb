# %%
import os
from huggingface_hub import InferenceClient
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-m3")

sentences = [
    "That is a happy dog",
    "That is a very happy person",
    "Today is a sunny day"
]

embeddings = model.encode(sentences)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 63628.96it/s]

# %%
embeddings
# Out:
# array([[-0.03470371, -0.00886351, -0.05242314, ...,  0.00899351,
#         -0.02396281,  0.02985839],
#        [-0.01356582,  0.01900945, -0.05800968, ...,  0.00523863,
#         -0.05689548,  0.00077096],
#        [-0.0214969 ,  0.02998874, -0.05638729, ...,  0.01443699,
#         -0.02131324, -0.00112453]], shape=(3, 1024), dtype=float32)
